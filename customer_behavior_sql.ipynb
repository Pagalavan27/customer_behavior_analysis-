# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://root:root@localhost/text

# %%
# %%sql
#
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 9 rows affected.
# [('da_project',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('text',),
#  ('uber',),
#  ('world',)]

# %%
# %%sql
#
# create database customer_behavior;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 1 rows affected.
# []

# %%
# %%sql
#
# use customer_behavior;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 0 rows affected.
# []

# %%
# %%sql
#
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 1 rows affected.
# [('customer',)]

# %%
# %%sql
#
# select * from customer limit 10
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 10 rows affected.
# [(1, 55, 'Male', 'Blouse', 'Clothing', 53, 'Kentucky', 'L', 'Gray', 'Winter', 3.1, 'Yes', 'Express', 'Yes', 14, 'Venmo', 'Fortnightly', 'Middle-aged', 14),
#  (2, 19, 'Male', 'Sweater', 'Clothing', 64, 'Maine', 'L', 'Maroon', 'Winter', 3.1, 'Yes', 'Express', 'Yes', 2, 'Cash', 'Fortnightly', 'Young Adults', 14),
#  (3, 50, 'Male', 'Jeans', 'Clothing', 73, 'Massachusetts', 'S', 'Maroon', 'Spring', 3.1, 'Yes', 'Free Shipping', 'Yes', 23, 'Credit Card', 'Weekly', 'Middle-aged', 7),
#  (4, 21, 'Male', 'Sandals', 'Footwear', 90, 'Rhode Island', 'M', 'Maroon', 'Spring', 3.5, 'Yes', 'Next Day Air', 'Yes', 49, 'PayPal', 'Weekly', 'Young Adults', 7),
#  (5, 45, 'Male', 'Blouse', 'Clothing', 49, 'Oregon', 'M', 'Turquoise', 'Spring', 2.7, 'Yes', 'Free Shipping', 'Yes', 31, 'PayPal', 'Annually', 'Middle-aged', 365),
# ...

# %%
# %%sql
#
# # What is the total revenue generated by male vs female customers?
#
# select gender, SUM(purchase_amount) as 'Revenue'
# from customer
# group by gender
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 2 rows affected.
# [('Male', Decimal('157890')), ('Female', Decimal('75191'))]

# %%
# %%sql
#
# # Which customers used a discount but still spent more than the average purchase amount
#
# select customer_id, purchase_amount
# from customer
# where discount_applied = 'Yes' and purchase_amount >= (select AVG(purchase_amount) from customer)
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 839 rows affected.
# [(2, 64),
#  (3, 73),
#  (4, 90),
#  (7, 85),
#  (9, 97),
#  (12, 68),
#  (13, 72),
#  (16, 81),
#  (20, 90),
#  (22, 62),
#  (24, 88),
#  (29, 94),
#  (32, 79),
#  (33, 67),
#  (35, 91),
#  (37, 69),
#  (40, 60),
#  (41, 76),
#  (43, 100),
#  (44, 69),
#  (55, 94),
#  (57, 73),
#  (58, 64),
#  (60, 79),
#  (62, 68),
#  (64, 79),
#  (65, 83),
#  (67, 94),
#  (70, 70),
#  (74, 85),
#  (76, 85),
#  (79, 91),
#  (80, 96),
#  (81, 72),
#  (82, 96),
#  (86, 95),
#  (90, 83),
#  (92, 99),
#  (93, 87),
#  (94, 62),
#  (95, 76),
#  (96, 100),
#  (97, 73),
#  (98, 92),
#  (99, 67),
#  (101, 98),
#  (102, 85),
#  (103, 67),
#  (104, 89),
#  (106, 96),
#  (108, 67),
#  (109, 79),
#  (110, 85),
#  (112, 75),
#  (113, 65),
#  (115, 95),
#  (116, 94),
#  (117, 86),
#  (120, 76),
#  (121, 84),
#  (122, 72),
#  (124, 89),
#  (125, 86),
#  (128, 89),
#  (130, 67),
#  (134, 65),
#  (135, 94),
#  (136, 81),
#  (137, 86),
# ...

# %%
# %%sql
#
# # Whichs are the top 5 products with the highest average review rating
#
# select item_purchased, ROUND(AVG(review_rating),2) as "Average Product Rating"
# from customer
# group by item_purchased
# order by AVG(review_rating) desc
# limit 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 5 rows affected.
# [('Gloves', 3.86),
#  ('Sandals', 3.84),
#  ('Boots', 3.82),
#  ('Hat', 3.8),
#  ('Skirt', 3.78)]

# %%
# %%sql
#
# # Compare the average purchase amounts between standard and express shipping
#
# select shipping_type, ROUND(AVG(purchase_amount),2) as 'Average Purchase Amount '
# from customer
# where shipping_type in ('Standard','Express')
# group by shipping_type
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 2 rows affected.
# [('Express', Decimal('60.48')), ('Standard', Decimal('58.46'))]

# %%
# %%sql
#
# # Do subscribe customers spend more? Compare average spend total revenue between subscibers and non-subscribers
#
# select subscription_status,
# COUNT(customer_id) as total_customers,
# ROUND(AVG(purchase_amount),2) as avg_spend,
# ROUND(SUM(purchase_amount),2) as total_revenue
# from customer
# group by subscription_status
# order by total_revenue, avg_spend desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 2 rows affected.
# [('Yes', 1053, Decimal('59.49'), Decimal('62645')),
#  ('No', 2847, Decimal('59.87'), Decimal('170436'))]

# %%
# %%sql
#
# # Which 5 products have the highest percentage of purchase with discount applied?
#
# select item_purchased,
# ROUND(100 * SUM(CASE WHEN discount_applied = 'Yes' THEN 1 ELSE 0 END)/COUNT(*) , 2) as discount_rate
# from customer
# group by item_purchased
# order by discount_rate desc
# limit 5
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 5 rows affected.
# [('Hat', Decimal('50.00')),
#  ('Sneakers', Decimal('49.66')),
#  ('Coat', Decimal('49.07')),
#  ('Sweater', Decimal('48.17')),
#  ('Pants', Decimal('47.37'))]

# %%
# %%sql
#
# # Segment customers into New, Returing and Loyal bassed on their total number of previous perchases, and show the count of each segment
#
# with customer_type as (
# select customer_id, previous_purchases,
# CASE
# 	WHEN previous_purchases = 1 THEN 'New'
# 	WHEN previous_purchases BETWEEN 2 AND 10 THEN 'Returning'
# 	ELSE 'Loyal'
# 	END AS customer_segment
# from customer
# )
#
#
# select customer_segment, count(*) as "Number of Customers"
# from customer_type
# group by customer_segment
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 3 rows affected.
# [('Loyal', 3116), ('Returning', 701), ('New', 83)]

# %%
# %%sql
#
# # What are the top 3 most purchased products with in each category?
#
# with item_counts as(
# select category,
# item_purchased,
# COUNT(customer_id) as total_orders,
# ROW_NUMBER() over(partition by category order by count(customer_id) DESC) as item_rank
# from customer
# group by category, item_purchased
# )
#
# select item_rank, category, item_purchased, total_orders
# from item_counts
# where item_rank <=3
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 11 rows affected.
# [(1, 'Accessories', 'Jewelry', 171),
#  (2, 'Accessories', 'Sunglasses', 161),
#  (3, 'Accessories', 'Belt', 161),
#  (1, 'Clothing', 'Blouse', 171),
#  (2, 'Clothing', 'Pants', 171),
#  (3, 'Clothing', 'Shirt', 169),
#  (1, 'Footwear', 'Sandals', 160),
#  (2, 'Footwear', 'Shoes', 150),
#  (3, 'Footwear', 'Sneakers', 145),
#  (1, 'Outerwear', 'Jacket', 163),
#  (2, 'Outerwear', 'Coat', 161)]

# %%
# %%sql
#
# # Are Customers who are repeat buyers (more than 5 previous purchases) also likely to subscribe?
#
# select subscription_status,
# count(customer_id) as repeat_buyers
# from customer
# where previous_purchases > 5
# group by subscription_status
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 2 rows affected.
# [('Yes', 958), ('No', 2518)]

# %%
# %%sql
#
# # What is the revenue contributed by each age group
#
# select age_group,
# SUM(purchase_amount) as total_revenue
# from customer
# group by age_group
# order by total_revenue desc
# Out:
#  * mysql+mysqlconnector://root:***@localhost/text
# 4 rows affected.
# [('Young Adults', Decimal('62143')),
#  ('Middle-aged', Decimal('59197')),
#  ('Adults', Decimal('55978')),
#  ('Senior', Decimal('55763'))]
